# %% [markdown]
# ### 12개월 데이터로 예측해보기

# %%
# 모델 불러오기
import torch
import torch.nn as nn
import matplotlib.pyplot as plt

class RNN(nn.Module):
    def __init__(self):
        super(RNN, self).__init__()
        # input size = 12
        self.rnn = nn.RNN(input_size=12, hidden_size=30, num_layers=2, batch_first=True)
        self.fc = nn.Linear(30, 1)

    def forward(self, x):
        x, _status = self.rnn(x)
        x = self.fc(x[:, -1])
        return x

# %%
# Load model
model = RNN()
model.load_state_dict(torch.load('noo_model_12m.pth'))
# Out:
# <All keys matched successfully>

# %%
# 모델 사용하기
# 1. 데이터 로드
import pandas as pd
import numpy as np

data = pd.read_csv('../../DATA/SMP_201004_202403_norm.csv')
data.head()
# norm -> value column
data['value'] = data['norm']
data.drop(['날짜', '통합'], axis=1, inplace=True)
data.head()
# Out:
#        norm     denorm        date     value
# 0 -1.165759  50.705398  2001-04-30 -1.165759
# 1 -1.123687  52.552364  2001-05-31 -1.123687
# 2 -1.153413  51.247385  2001-06-30 -1.153413
# 3 -1.240408  47.428339  2001-07-31 -1.240408
# 4 -1.357382  42.293200  2001-08-31 -1.357382

# %%
data['value'].tolist()
# Out:
# [-1.1657591092300412,
#  -1.1236866855146113,
#  -1.1534130844046464,
#  -1.2404079208442451,
#  -1.3573823337606423,
#  -1.3061867579742663,
#  -1.2517299807223572,
#  -1.246997678516826,
#  -1.0386740430647623,
#  -0.9969318086332924,
#  -1.1333589674040083,
#  -1.1704372369788658,
#  -1.2557524135755815,
#  -1.2219689276534222,
#  -1.4277970150371757,
#  -1.408165994616604,
#  -1.4988782696149063,
#  -1.3924052399310187,
#  -1.2658096724398749,
#  -1.0919334788798845,
#  -1.0881930219046778,
#  -1.0574966580223952,
#  -1.0680410186312148,
#  -1.0312044213916896,
#  -1.047557163527338,
#  -1.0213962132042762,
#  -1.1742491858600088,
#  -1.4093687833264796,
#  -1.457490543949632,
#  -1.3476788932139068,
#  -1.2406649398170349,
#  -1.1623207744659607,
#  -1.0495213476720946,
#  -1.0723025854746036,
#  -0.94621135110026,
#  -0.9460854637767102,
#  -1.016426366886258,
#  -1.087610841048121,
#  -1.1253999616256076,
#  -1.1882267089532643,
#  -1.257546261915289,
#  -1.187127405174833,
#  -0.982651405932667,
#  -0.9331720243177024,
#  -0.8719173589491567,
#  -0.7896263735584453,
#  -0.8890110788381367,
#  -0.9148584525712528,
#  -1.1271079804342712,
#  -1.2499645479240125,
#  -1.116957827219168,
#  -1.0598196103583657,
#  -1.0896727256638838,
#  -0.8745956217414949,
#  -0.8562298381210012,
#  -0.583077525342438,
#  -0.4735514416465988,
#  -0.4721311841251177,
#  -0.4383914130423202,
#  -0.3733272362550117,
#  -0.4200051864116706,
#  -0.458637821517737,
#  -0.6861488576495971,
#  -0.8332848949014764,
#  -0.6461202440429765,
#  -0.6253314693979148,
#  -0.3319352680785477,
#  -0.603691221629794,
#  -0.7540339955977926,
#  -0.8330778479718768,
#  -0.7932142336621801,
#  -0.6868353314757325,
#  -0.6909355889475872,
#  -0.6469717171660359,
#  -0.6114361524099634,
#  -0.340591367185796,
#  -0.3547144762555172,
#  -0.2462854453331426,
#  -0.2237340292379426,
#  -0.6043745978751032,
#  -0.5180413988843886,
#  -0.4367196256926076,
#  -0.5715725381002668,
#  -0.5804564292892849,
#  -0.6531221033738179,
#  -0.6615504103992964,
#  -0.4647380517502799,
#  -0.2531192077862334,
#  -0.2198615638478577,
#  -0.2535747919497727,
#  -0.0093816802926596,
#  -0.2499301186414576,
#  -0.3244181293801478,
#  -0.2754428317996633,
#  -0.3328464364056266,
#  -0.247424405741991,
#  -0.2052828706145972,
#  0.0108918149848431,
#  0.0735346374715093,
#  0.1837860050480418,
#  0.2140823519234111,
#  0.0903912515224666,
#  0.2400506492451564,
#  -0.0556234728919077,
#  -0.506424002714134,
#  -0.5317089237905702,
#  -0.5039182898146674,
#  -0.3884277043574322,
#  -0.5066517947959038,
#  -0.3114339807192753,
#  -0.4567653288883407,
#  -0.4032341896724621,
#  -0.3950336747287531,
#  -0.4549429922341831,
#  -0.4221409324593471,
#  -0.603691221629794,
#  -0.7055142821808477,
#  -0.7052864900990778,
#  -0.697769351400678,
#  -0.8854700267789067,
#  -1.0465190285900812,
#  -1.172943633972262,
#  -1.186383366796674,
#  -0.7913918970080226,
#  -0.7114368763068596,
#  -0.6023244691391758,
#  -0.4023230213453835,
#  -0.5815953896981336,
#  -0.5189525672114675,
#  -0.4276079424218197,
#  -0.3266960501978446,
#  -0.1779478208022341,
#  -0.0708855423704774,
#  0.1338995391404786,
#  0.5735382569559899,
#  0.9323107857432597,
#  1.196777392677875,
#  2.174005423469867,
#  2.0699044421011163,
#  2.2831178306375515,
#  0.8760461415461449,
#  0.6341309507067288,
#  1.1382348276630636,
#  2.1835726909041946,
#  2.996334838658466,
#  3.41159980372462,
#  3.1961084943704887,
#  3.775611550392592,
#  3.1646731870862705,
#  3.455108091342632,
#  2.5972431113979604,
#  1.4345923260454374,
#  0.951217528530144,
#  1.0307169650677677,
#  1.176276105318603,
#  1.032767093803695,
#  0.8954084684965689,
#  0.8001913783168362,
#  0.4320793741770091,
#  0.6660218421544861,
#  0.8241095469026545,
#  0.4020108193834095,
#  0.7423321895473338]

# %%
data[pd.to_datetime(data['date'].values).strftime('%Y-%m') == '2020-04'].index[0]
# Out:
# 228

# %%
def denorms(x):
    return x * 43.89968 + 101.88185

# %%
def predict_df(start_date, pred_length):
    # date가 '2023-04-30' 이후이면 에러 출력
    if start_date > '2023-04-30':
        print('date error: 2023-04-30 이전으로만 입력해주세요 (학습 기간 : 12개월)')
        return
    else:
        start_idx = data[data['date'] == start_date].index.item()
        pred_total = data['norm'][start_idx: start_idx+12].tolist()
        for i in range(pred_length):
            values = torch.tensor(pred_total[-12:]).unsqueeze(0).float()
            pred = model(values.unsqueeze(0))
            pred_total = np.append(pred_total, pred.item())
        pred_total_denorm = denorms(pred_total).tolist()
        pred_df = pd.DataFrame({'date': pd.date_range(start_date, periods=pred_length, freq='M'), 'value': pred_total_denorm[-pred_length:]})
        return pred_df
    
predict_df('2023-04-30', 15)
# Out:
#          date       value
# 0  2023-04-30  142.589826
# 1  2023-05-31  133.898377
# 2  2023-06-30  143.171706
# 3  2023-07-31  133.011273
# 4  2023-08-31  115.205927
# 5  2023-09-30  131.433807
# 6  2023-10-31  127.234014
# 7  2023-11-30  126.235513
# 8  2023-12-31  144.897569
# 9  2024-01-31  133.914435
# 10 2024-02-29  149.511157
# 11 2024-03-31  173.682276
# 12 2024-04-30  168.941821
# 13 2024-05-31  173.452175
# 14 2024-06-30  182.195109

# %%
# 입력 : 시작일, 기간
# 출력 : 데이터프레임 (date, pred)

def predict(start_date, period):
    # Load data
    data = pd.read_csv('../../DATA/SMP_201004_202403_norm.csv')
    
    # 데이터 전처리
    data['date'] = pd.to_datetime(data['date'])
    data.set_index('date', inplace=True)
    data = data[start_date:]
    data = data['value']
    data = data.values

    # 데이터셋 생성
    sequence = 12
    x = []
    y = []
    for i in range(len(data) - sequence):
        x.append(data[i:i+sequence])
        y.append(data[i+sequence])

    x = np.array(x)
    y = np.array(y)

    x = x.reshape(-1, 12, 1)
    y = y.reshape(-1, 1)

    # 예측
    pred = []
    for i in range(period):
        x_input = x[-1]
        x_input = x_input.reshape(1, 12, 1)
        x_input = torch.Tensor(x_input)
        y_pred = model(x_input)
        pred.append(y_pred.item())
        x = np.append(x, y_pred.item()).reshape(-1, 12, 1)

    # 시각화
    plt.figure(figsize=(12, 6))
    plt.plot(y, label='actual')
    plt.plot(pred, label='prediction')
    plt.legend()
    plt.show()

    # 결과
    result = pd.DataFrame()
    result['date'] = pd.date_range(start=start_date, periods=period, freq='M')
    result['pred'] = pred
    result['pred'] = denorms(result['pred'])
    return result

# %%
# 예측
result = predict('2019-01-01', 12)
print(result)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\wjs31\anaconda3\envs\Torch_NLP\lib\site-packages\pandas\core\indexes\base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File c:\Users\wjs31\anaconda3\envs\Torch_NLP\lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\wjs31\anaconda3\envs\Torch_NLP\lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'value'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[15], line 2
#       1 # 예측
# ----> 2 result = predict('2019-01-01', 12)
#       3 print(result)
#
# Cell In[14], line 12, in predict(start_date, period)
#      10 data.set_index('date', inplace=True)
#      11 data = data[start_date:]
# ---> 12 data = data['value']
#      13 data = data.values
#      15 # 데이터셋 생성
#
# File c:\Users\wjs31\anaconda3\envs\Torch_NLP\lib\site-packages\pandas\core\frame.py:3761, in DataFrame.__getitem__(self, key)
#    3759 if self.columns.nlevels > 1:
#    3760     return self._getitem_multilevel(key)
# -> 3761 indexer = self.columns.get_loc(key)
#    3762 if is_integer(indexer):
#    3763     indexer = [indexer]
#
# File c:\Users\wjs31\anaconda3\envs\Torch_NLP\lib\site-packages\pandas\core\indexes\base.py:3655, in Index.get_loc(self, key)
#    3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
# -> 3655     raise KeyError(key) from err
#    3656 except TypeError:
#    3657     # If we have a listlike key, _check_indexing_error will raise
#    3658     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3659     #  the TypeError.
#    3660     self._check_indexing_error(key)
#
# KeyError: 'value'
